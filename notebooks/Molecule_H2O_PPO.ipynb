# %% [markdown]
# # Variational Quantum Eigensolver using classical optimisers
# ### Estimation of ground state energy, Hamiltonian $H_{2}O$

# %%
#Import libraries
import torch
from matplotlib import pyplot as plt
from qiskit import QuantumCircuit
import numpy as np
from math import pi
import matplotlib.pylab as plt
from itertools import product
from qiskit.quantum_info import Operator
from tqdm.auto import tqdm
import warnings
warnings.filterwarnings("ignore")
import sys
sys.path.insert(1, '../src/')
from utils.functions import *
from models.models_rl import *

from scipy.linalg import eigh
from qiskit_algorithms.optimizers import SPSA, COBYLA, L_BFGS_B
from qiskit import QuantumCircuit
from qiskit.quantum_info import SparsePauliOp, Statevector, Operator
from qiskit_nature.units import DistanceUnit
from qiskit_nature.second_q.drivers import PySCFDriver
from qiskit_nature.second_q.mappers import JordanWignerMapper
from qiskit_nature.second_q.operators import PolynomialTensor
from qiskit.primitives import Estimator
from qiskit_nature.second_q.circuit.library import UCCSD, HartreeFock
from qiskit.circuit.library import TwoLocal

# %%
# Define the H2O molecule geometry
driver = PySCFDriver(
    atom="O 0 0 0; H 0.757 0.586 0; H -0.757 0.586 0",
    basis="sto3g",
    charge=0,
    spin=0,
    unit=DistanceUnit.ANGSTROM
)
# Run the driver to get the electronic structure problem
problem = driver.run()

#Obtaining the Hamiltonian
hamiltonian = problem.hamiltonian
second_q_op = hamiltonian.second_q_op()

#Converting to qubit Hamiltonian
mapper = JordanWignerMapper()
H = mapper.map(second_q_op)


nuclear_repulsion_energy = hamiltonian.nuclear_repulsion_energy
hamiltonian.electronic_integrals.alpha += PolynomialTensor({"": nuclear_repulsion_energy})
mapper = JordanWignerMapper()
second_q_op = hamiltonian.second_q_op()
H = mapper.map(second_q_op)

# %%
# Set up the initial state and, the UCCSD or TwoLocal ansatz for H2
num_spatial_orbitals = problem.num_spatial_orbitals
num_particles = problem.num_particles
mapper = JordanWignerMapper()

initial_state = HartreeFock(
    num_spatial_orbitals,
    num_particles,
    mapper
)


ansatz = UCCSD(
    num_spatial_orbitals=num_spatial_orbitals,
    num_particles=num_particles,
    qubit_mapper=mapper,
    initial_state=initial_state
    )

ansatz = TwoLocal(H.num_qubits, rotation_blocks="ry", entanglement_blocks="cz")
num_qubits = ansatz.num_qubits

print('Initial state:',Statevector.from_instruction(initial_state))
initial_circuit = ansatz.decompose()
print('Initial Circuit Ansatz')
#initial_circuit.draw('mpl')
# Out:
# Initial state: Statevector([0.+0.j, 0.+0.j, 0.+0.j, ..., 0.+0.j, 0.+0.j, 0.+0.j],
#             dims=(2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2))
# Initial Circuit Ansatz

# %%
def create_circuit_ansatz(thetas, initial_state):

    # Create circuit
    circ = QuantumCircuit(ansatz.num_qubits)
    # Apply the initial state (HartreeFock)
    circ.compose(initial_state, inplace=True)
    # Apply the UCCSD ansatz with the generated parameters
    circ = ansatz.assign_parameters(thetas.squeeze()).compose(circ)
    return circ


n_thetas = ansatz.num_parameters
circ_visualization = create_circuit_ansatz(np.zeros(n_thetas)[np.newaxis,:], initial_state)
#circ_visualization.decompose().draw('mpl')

# %%
def target_function(thetas):
    circuit = create_circuit_ansatz
    new_exp_values, new_eigenvalue = get_expectation_values_hamiltonian(circuit, np.array(thetas)[np.newaxis,:], initial_state, H)
    return -new_eigenvalue

# %%
#Estimate the ground state energy
#Due to the computational cost, we will not calculate the ground state energy and the value of −74.96, a value found in the literature, will be used.

ground_state_energy = -74.96
if False:
    eigenvalues, eigenvectors = eigh(H.to_matrix())
    ground_state_energy = np.min(eigenvalues)
    ground_state = eigenvectors[:, np.argmin(eigenvalues)]
print(f"Ground state energy: {ground_state_energy}")
# Out:
# Ground state energy: -74.96

# %% [markdown]
# We set up our experiment, and calculate metrics of interest.

# %%
n_run = 5
n_total_timesteps = 200

params = {'lr': 0.000001,
          'n_steps': 20,
          'batch_size':10,
          'gae_lambda': 0.95,
          'gamma':0.99,  
          'ent_coef':0.01,
          'clip_range':0.3,
          'n_run':n_run,
          'n_total_timesteps': n_total_timesteps,
          'n_epochs': 20
          }

metrics = {
    'best_eigenvalue_runs': np.zeros(n_run),
    'history_best_eigenvalue_runs': np.zeros((n_run, n_total_timesteps)),
    'value_losses_runs':np.zeros((n_run,n_total_timesteps)),
    'best_thetas_runs': np.zeros((n_run,n_thetas)),
    }

for iter_run in range(n_run):

    best_eigenvalue, eigenvalue_history = float('inf'), []
    best_thetas, thetas_history = np.zeros(n_thetas), []
    X_train, y_train = [], []
    
    print('run',iter_run+1)
    # Create the environment
    env = DummyVecEnv([lambda: OptimizationEnv(target_function, n_thetas)])
    metrics_callback = MetricsCallback()
    
    # Create the model
    model = PPO(
        CustomActorCriticPolicy, 
        env,
        verbose=1,
        learning_rate=params['lr'],  # Default learning rate; can be tuned further
        n_steps=params['n_steps'],  # Number of steps to run for each environment per update
        batch_size=params['batch_size'],  # Minibatch size for each gradient update
        gae_lambda=params['gae_lambda'],  # Lambda for GAE
        gamma=params['gamma'],  # Discount factor
        ent_coef=params['ent_coef'],  # Entropy coefficient for exploration
        clip_range=params['clip_range'],  # Clipping range for PPO
        n_epochs = params['n_epochs']
    )

    model.learn(total_timesteps=n_total_timesteps, callback=metrics_callback )
   
    X_train = np.array(env.envs[0].states) #Thetas
    y_train = np.abs(env.envs[0].rewards) #Eigenvalue
    best_thetas = env.envs[0].best_thetas
    best_eigenvalue = env.envs[0].best_value

    #We only keep results until n_total_timesteps
    metrics['best_eigenvalue_runs'][iter_run] = (env.envs[0]).history[-1]
    metrics['history_best_eigenvalue_runs'][iter_run,:] = env.envs[0].history
    metrics['best_thetas_runs'][iter_run,:] = best_thetas
    metrics['value_losses_runs'][iter_run] = metrics_callback.value_losses
# Out:
# run 1
# Using cpu device
# ---------------------------
# | time/              |    |
# |    fps             | 9  |
# |    iterations      | 1  |
# |    time_elapsed    | 2  |
# |    total_timesteps | 20 |
# ---------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 9            |
# |    iterations           | 2            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 40           |
# | train/                  |              |
# |    approx_kl            | 0.0002979666 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.3          |
# |    entropy_loss         | -79.5        |
# |    explained_variance   | -0.102       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 1.47e+03     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0102      |
# |    std                  | 1            |
# |    value_loss           | 2.88e+03     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 9             |
# |    iterations           | 3             |
# |    time_elapsed         | 6             |
# |    total_timesteps      | 60            |
# | train/                  |               |
# |    approx_kl            | 0.00018572509 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -79.5         |
# |    explained_variance   | -0.291        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 1.52e+03      |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.00703      |
# |    std                  | 1             |
# |    value_loss           | 2.82e+03      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 8             |
# |    iterations           | 4             |
# |    time_elapsed         | 8             |
# |    total_timesteps      | 80            |
# | train/                  |               |
# |    approx_kl            | 0.00015586913 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -79.5         |
# |    explained_variance   | -0.0493       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 1.49e+03      |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -0.00623      |
# |    std                  | 1             |
# |    value_loss           | 2.86e+03      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 8             |
# |    iterations           | 5             |
# |    time_elapsed         | 12            |
# |    total_timesteps      | 100           |
# | train/                  |               |
# |    approx_kl            | 0.00035344064 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -79.5         |
# |    explained_variance   | -0.0155       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 1.81e+03      |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -0.00975      |
# |    std                  | 1             |
# |    value_loss           | 3.33e+03      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 7             |
# |    iterations           | 6             |
# |    time_elapsed         | 15            |
# |    total_timesteps      | 120           |
# | train/                  |               |
# |    approx_kl            | 0.00020964147 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -79.5         |
# |    explained_variance   | -0.138        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 1.47e+03      |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -0.00782      |
# |    std                  | 1             |
# |    value_loss           | 2.78e+03      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 7             |
# |    iterations           | 7             |
# |    time_elapsed         | 18            |
# |    total_timesteps      | 140           |
# | train/                  |               |
# |    approx_kl            | 0.00011737943 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -79.5         |
# |    explained_variance   | 0.249         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 1.45e+03      |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -0.00545      |
# |    std                  | 1             |
# |    value_loss           | 2.89e+03      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 7             |
# |    iterations           | 8             |
# |    time_elapsed         | 21            |
# |    total_timesteps      | 160           |
# | train/                  |               |
# |    approx_kl            | 0.00020109415 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -79.5         |
# |    explained_variance   | -0.302        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 1.46e+03      |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.00753      |
# |    std                  | 1             |
# |    value_loss           | 2.94e+03      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 7             |
# |    iterations           | 9             |
# |    time_elapsed         | 24            |
# |    total_timesteps      | 180           |
# | train/                  |               |
# |    approx_kl            | 0.00011473298 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -79.5         |
# |    explained_variance   | 0.0329        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 1.58e+03      |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -0.00551      |
# |    std                  | 1             |
# |    value_loss           | 3.15e+03      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 7             |
# |    iterations           | 10            |
# |    time_elapsed         | 27            |
# |    total_timesteps      | 200           |
# | train/                  |               |
# |    approx_kl            | 0.00031554402 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -79.5         |
# |    explained_variance   | -0.00652      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 1.34e+03      |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -0.00959      |
# |    std                  | 1             |
# |    value_loss           | 2.89e+03      |
# -------------------------------------------
# run 2
# Using cpu device
# ---------------------------
# | time/              |    |
# |    fps             | 7  |
# |    iterations      | 1  |
# |    time_elapsed    | 2  |
# |    total_timesteps | 20 |
# ---------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 2            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 40           |
# | train/                  |              |
# |    approx_kl            | 0.0004159987 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.3          |
# |    entropy_loss         | -79.5        |
# |    explained_variance   | -0.184       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 1.58e+03     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.012       |
# |    std                  | 1            |
# |    value_loss           | 3.17e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 3            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 60           |
# | train/                  |              |
# |    approx_kl            | 0.0003947109 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.3          |
# |    entropy_loss         | -79.5        |
# |    explained_variance   | 0.0653       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 1.79e+03     |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0108      |
# |    std                  | 1            |
# |    value_loss           | 3.4e+03      |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 4             |
# |    time_elapsed         | 11            |
# |    total_timesteps      | 80            |
# | train/                  |               |
# |    approx_kl            | 0.00021054744 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -79.5         |
# |    explained_variance   | -0.0128       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 1.68e+03      |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -0.00689      |
# |    std                  | 1             |
# |    value_loss           | 3.44e+03      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 5             |
# |    time_elapsed         | 14            |
# |    total_timesteps      | 100           |
# | train/                  |               |
# |    approx_kl            | 0.00023652613 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -79.5         |
# |    explained_variance   | 0.0422        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 1.62e+03      |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -0.00818      |
# |    std                  | 1             |
# |    value_loss           | 3.38e+03      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 6             |
# |    time_elapsed         | 17            |
# |    total_timesteps      | 120           |
# | train/                  |               |
# |    approx_kl            | 0.00038425624 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -79.5         |
# |    explained_variance   | -0.093        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 1.43e+03      |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -0.0108       |
# |    std                  | 1             |
# |    value_loss           | 3.11e+03      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 7             |
# |    time_elapsed         | 20            |
# |    total_timesteps      | 140           |
# | train/                  |               |
# |    approx_kl            | 0.00021148621 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -79.5         |
# |    explained_variance   | -0.0399       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 1.63e+03      |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -0.00723      |
# |    std                  | 1             |
# |    value_loss           | 3.34e+03      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 8             |
# |    time_elapsed         | 23            |
# |    total_timesteps      | 160           |
# | train/                  |               |
# |    approx_kl            | 0.00014802814 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -79.5         |
# |    explained_variance   | -0.14         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 1.79e+03      |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.0067       |
# |    std                  | 1             |
# |    value_loss           | 3.3e+03       |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 9            |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 180          |
# | train/                  |              |
# |    approx_kl            | 0.0001848042 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.3          |
# |    entropy_loss         | -79.5        |
# |    explained_variance   | -0.011       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 1.61e+03     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00734     |
# |    std                  | 1            |
# |    value_loss           | 3.16e+03     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 10            |
# |    time_elapsed         | 30            |
# |    total_timesteps      | 200           |
# | train/                  |               |
# |    approx_kl            | 0.00020028054 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -79.5         |
# |    explained_variance   | 3.73e-05      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 1.6e+03       |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -0.00741      |
# |    std                  | 1             |
# |    value_loss           | 3.16e+03      |
# -------------------------------------------
# run 3
# Using cpu device
# ---------------------------
# | time/              |    |
# |    fps             | 7  |
# |    iterations      | 1  |
# |    time_elapsed    | 2  |
# |    total_timesteps | 20 |
# ---------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 2             |
# |    time_elapsed         | 5             |
# |    total_timesteps      | 40            |
# | train/                  |               |
# |    approx_kl            | 0.00022948682 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -79.5         |
# |    explained_variance   | 0.0128        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 1.63e+03      |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.00946      |
# |    std                  | 1             |
# |    value_loss           | 3.47e+03      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 3            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 60           |
# | train/                  |              |
# |    approx_kl            | 0.0002907425 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.3          |
# |    entropy_loss         | -79.5        |
# |    explained_variance   | -0.0648      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 1.65e+03     |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00893     |
# |    std                  | 1            |
# |    value_loss           | 3.29e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 4            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 80           |
# | train/                  |              |
# |    approx_kl            | 0.0002823472 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.3          |
# |    entropy_loss         | -79.5        |
# |    explained_variance   | -0.0387      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 1.88e+03     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00855     |
# |    std                  | 1            |
# |    value_loss           | 3.91e+03     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 5             |
# |    time_elapsed         | 15            |
# |    total_timesteps      | 100           |
# | train/                  |               |
# |    approx_kl            | 0.00016608536 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -79.5         |
# |    explained_variance   | 0.0594        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 1.81e+03      |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -0.00635      |
# |    std                  | 1             |
# |    value_loss           | 3.69e+03      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 6             |
# |    time_elapsed         | 18            |
# |    total_timesteps      | 120           |
# | train/                  |               |
# |    approx_kl            | 0.00036088226 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -79.5         |
# |    explained_variance   | 0.0825        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 1.66e+03      |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -0.0101       |
# |    std                  | 1             |
# |    value_loss           | 3.36e+03      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 7            |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 140          |
# | train/                  |              |
# |    approx_kl            | 0.0004069805 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.3          |
# |    entropy_loss         | -79.5        |
# |    explained_variance   | 0.00673      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 1.55e+03     |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.011       |
# |    std                  | 1            |
# |    value_loss           | 3.26e+03     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 8             |
# |    time_elapsed         | 25            |
# |    total_timesteps      | 160           |
# | train/                  |               |
# |    approx_kl            | 0.00029908417 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -79.5         |
# |    explained_variance   | 0.0244        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 1.49e+03      |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.0092       |
# |    std                  | 1             |
# |    value_loss           | 3.33e+03      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 9            |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 180          |
# | train/                  |              |
# |    approx_kl            | 0.0003080666 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.3          |
# |    entropy_loss         | -79.5        |
# |    explained_variance   | 0.0103       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 1.96e+03     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00905     |
# |    std                  | 1            |
# |    value_loss           | 3.93e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 10           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 200          |
# | train/                  |              |
# |    approx_kl            | 0.0004164666 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.3          |
# |    entropy_loss         | -79.5        |
# |    explained_variance   | 0.021        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 1.66e+03     |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.0101      |
# |    std                  | 1            |
# |    value_loss           | 3.4e+03      |
# ------------------------------------------
# run 4
# Using cpu device
# ---------------------------
# | time/              |    |
# |    fps             | 7  |
# |    iterations      | 1  |
# |    time_elapsed    | 2  |
# |    total_timesteps | 20 |
# ---------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 2             |
# |    time_elapsed         | 5             |
# |    total_timesteps      | 40            |
# | train/                  |               |
# |    approx_kl            | 0.00023483337 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -79.5         |
# |    explained_variance   | 0.129         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 1.89e+03      |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.00836      |
# |    std                  | 1             |
# |    value_loss           | 3.77e+03      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 3            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 60           |
# | train/                  |              |
# |    approx_kl            | 0.0003717661 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.3          |
# |    entropy_loss         | -79.5        |
# |    explained_variance   | 0.179        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 1.58e+03     |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.01        |
# |    std                  | 1            |
# |    value_loss           | 3.47e+03     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 4             |
# |    time_elapsed         | 11            |
# |    total_timesteps      | 80            |
# | train/                  |               |
# |    approx_kl            | 0.00011845529 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -79.5         |
# |    explained_variance   | -0.115        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 1.61e+03      |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -0.00585      |
# |    std                  | 1             |
# |    value_loss           | 3.21e+03      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 5             |
# |    time_elapsed         | 14            |
# |    total_timesteps      | 100           |
# | train/                  |               |
# |    approx_kl            | 0.00031020044 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -79.5         |
# |    explained_variance   | -0.0292       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 1.69e+03      |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -0.00904      |
# |    std                  | 1             |
# |    value_loss           | 3.29e+03      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 6             |
# |    time_elapsed         | 18            |
# |    total_timesteps      | 120           |
# | train/                  |               |
# |    approx_kl            | 0.00036266446 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -79.5         |
# |    explained_variance   | -0.205        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 1.53e+03      |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -0.0101       |
# |    std                  | 1             |
# |    value_loss           | 3.04e+03      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 7            |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 140          |
# | train/                  |              |
# |    approx_kl            | 0.0002511561 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.3          |
# |    entropy_loss         | -79.5        |
# |    explained_variance   | -0.164       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 1.78e+03     |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00789     |
# |    std                  | 1            |
# |    value_loss           | 3.17e+03     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 8             |
# |    time_elapsed         | 24            |
# |    total_timesteps      | 160           |
# | train/                  |               |
# |    approx_kl            | 0.00033709704 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -79.5         |
# |    explained_variance   | -0.159        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 1.65e+03      |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.00981      |
# |    std                  | 1             |
# |    value_loss           | 3.44e+03      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 9            |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 180          |
# | train/                  |              |
# |    approx_kl            | 0.0002396673 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.3          |
# |    entropy_loss         | -79.5        |
# |    explained_variance   | 0.0131       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 1.6e+03      |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00771     |
# |    std                  | 1            |
# |    value_loss           | 3.17e+03     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 10            |
# |    time_elapsed         | 30            |
# |    total_timesteps      | 200           |
# | train/                  |               |
# |    approx_kl            | 0.00021587312 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -79.5         |
# |    explained_variance   | 0.00103       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 1.53e+03      |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -0.00743      |
# |    std                  | 1             |
# |    value_loss           | 3.01e+03      |
# -------------------------------------------
# run 5
# Using cpu device
# ---------------------------
# | time/              |    |
# |    fps             | 6  |
# |    iterations      | 1  |
# |    time_elapsed    | 2  |
# |    total_timesteps | 20 |
# ---------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 2            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 40           |
# | train/                  |              |
# |    approx_kl            | 7.936954e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.3          |
# |    entropy_loss         | -79.5        |
# |    explained_variance   | -0.148       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 2.09e+03     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00525     |
# |    std                  | 1            |
# |    value_loss           | 4.14e+03     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 3             |
# |    time_elapsed         | 9             |
# |    total_timesteps      | 60            |
# | train/                  |               |
# |    approx_kl            | 0.00011360348 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -79.5         |
# |    explained_variance   | -0.574        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 2.2e+03       |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.00528      |
# |    std                  | 1             |
# |    value_loss           | 4.45e+03      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 4             |
# |    time_elapsed         | 12            |
# |    total_timesteps      | 80            |
# | train/                  |               |
# |    approx_kl            | 0.00015332998 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -79.5         |
# |    explained_variance   | 0.0583        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 2.1e+03       |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -0.0065       |
# |    std                  | 1             |
# |    value_loss           | 4.27e+03      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 5             |
# |    time_elapsed         | 15            |
# |    total_timesteps      | 100           |
# | train/                  |               |
# |    approx_kl            | 0.00018973352 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -79.5         |
# |    explained_variance   | 0.00142       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 2.06e+03      |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -0.00711      |
# |    std                  | 1             |
# |    value_loss           | 4.02e+03      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 6            |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 120          |
# | train/                  |              |
# |    approx_kl            | 9.641051e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.3          |
# |    entropy_loss         | -79.5        |
# |    explained_variance   | -0.185       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 2.31e+03     |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.0049      |
# |    std                  | 1            |
# |    value_loss           | 4.3e+03      |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 7             |
# |    time_elapsed         | 22            |
# |    total_timesteps      | 140           |
# | train/                  |               |
# |    approx_kl            | 0.00012197792 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -79.5         |
# |    explained_variance   | -0.0732       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 1.99e+03      |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -0.0054       |
# |    std                  | 1             |
# |    value_loss           | 4.03e+03      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 8             |
# |    time_elapsed         | 25            |
# |    total_timesteps      | 160           |
# | train/                  |               |
# |    approx_kl            | 0.00016707779 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -79.5         |
# |    explained_variance   | -0.065        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 2.36e+03      |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.00624      |
# |    std                  | 1             |
# |    value_loss           | 3.98e+03      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 9             |
# |    time_elapsed         | 28            |
# |    total_timesteps      | 180           |
# | train/                  |               |
# |    approx_kl            | 0.00014076233 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -79.5         |
# |    explained_variance   | 0.026         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 1.91e+03      |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -0.00648      |
# |    std                  | 1             |
# |    value_loss           | 4.16e+03      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 10            |
# |    time_elapsed         | 32            |
# |    total_timesteps      | 200           |
# | train/                  |               |
# |    approx_kl            | 0.00016027689 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.3           |
# |    entropy_loss         | -79.5         |
# |    explained_variance   | 0.0402        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 1.96e+03      |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -0.00685      |
# |    std                  | 1             |
# |    value_loss           | 4.04e+03      |
# -------------------------------------------

# %%
fig, ax = plt.subplots(2,1,figsize=(10,7), facecolor='white', constrained_layout = True, sharex=False, sharey=False)

plt.suptitle('Eigenvalues during the Optimisation RL PPO')
ax[0].set_title(r'Hamiltonian: $H_{2}O$')
ax[0].plot(np.arange(n_total_timesteps), np.mean(metrics['history_best_eigenvalue_runs'],0), '-o', linewidth=1.3, color='k', markersize=2.5, label = 'Eigenvalue')
ax[0].axhline(ground_state_energy, linestyle='--',color='r', label='Ground state energy $E_{0}$')

ax[1].plot(np.arange(n_total_timesteps), np.mean(metrics['history_best_eigenvalue_runs'],0) - ground_state_energy, '-o', linewidth=1.3, color='k', markersize=2.5, label = 'Eigenvalue - $E_{0}$')
ax[1].set_yscale('log')
ax[0].set_ylabel('Eigenvalue')
ax[1].set_ylabel('Eigenvalue - $E_{0}$')
ax[1].set_xlabel('Number of iterations')

ax[0].legend(loc='upper right')
ax[1].legend(loc='upper right')

plt.legend()
plt.show()

# %%
data_plot = {   'history_best_eigenvalue_runs':metrics['history_best_eigenvalue_runs'],
                'best_thetas_runs': metrics['best_thetas_runs'],
                'best_eigenvalue_runs':metrics['best_eigenvalue_runs'],
                'real_ground_state_energy':ground_state_energy,

            } 
if True:
    with open("../results/vqe/results_hamiltonian_H2O_"+ str(num_qubits)+"qubits_ppo.json", "w") as outfile: 
        json.dump(data_plot, outfile, cls=CustomEncoder)

# %%
import mlflow
#Metrics resume
metrics_reg= {
    'mean_eigenvalue_runs': -np.mean(np.abs(metrics['best_eigenvalue_runs'])),
    'std_eigenvalue_runs': np.std(np.abs(metrics['best_eigenvalue_runs'])),
        }

params['size_final_dataset'] =  y_train.shape[0]

mlflow.set_tracking_uri(uri="http://127.0.0.1:8080")
mlflow.set_experiment("VQE_H2O")

with mlflow.start_run(run_name='VQE_H2O_RL_PPO'):
    mlflow.log_params(params)
    mlflow.log_metrics(metrics_reg)
# Out:
# 2024/09/29 20:31:49 INFO mlflow.tracking._tracking_service.client: 🏃 View run VQE_H2O_RL_PPO at: http://127.0.0.1:8080/#/experiments/530387561206499386/runs/21e4935038b246a2924879dfdd58fec6.
# 2024/09/29 20:31:49 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://127.0.0.1:8080/#/experiments/530387561206499386.
